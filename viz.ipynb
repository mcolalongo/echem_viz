# %%
from readclass import Echem
import os
# import matplotlib.pyplot as plt
# from matplotlib.pyplot import cm 
# import numpy as np

# %%
# collect folder paths
lstF = []
for i in os.listdir():
    if (os.path.isdir(i)) & ("Sample" in i):
        lstF.append(i)

# gather all the files in folders in list and split in samples-wise
# sample1 = []
# sample2 = []
# sample3 = []
# sample4 = []

# for i in lstF:
#     for j in os.listdir(i):
#         if "Sample_1" in j:
#             sample1.append(os.path.join(i, j))
#         elif "Sample_2" in j:
#             sample2.append(os.path.join(i, j))
#         elif "Sample_3" in j:
#             sample3.append(os.path.join(i, j))
#         else:
#             sample4.append(os.path.join(i, j))

# %%
sample2c = Echem(lstF[0], 1, 22)
print(sample2c.plotDqDvFilter())
sample2d = Echem(lstF[-1], 1, 22)
print(sample2d.plotDqDvFilter())
# Out:
# None
# None

# %%
lstF
# Out:
# ['Sample_2_charge_data',
#  'Sample_1_charge_data',
#  'Sample_4_discharge_data',
#  'Sample_4_charge_data',
#  'Sample_3_discharge_data',
#  'Sample_1_discharge_data',
#  'Sample_3_charge_data',
#  'Sample_2_discharge_data']
